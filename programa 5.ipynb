# %%
datos_p ={
    "nombre": "Mayra Naomi",
    "matricula": 231690087-3,
    "edad": 17,
    "peso": 60,
    "teléfono": 3111565245,
    "domicilio": "islas lilas",
    "carrera": "CDIA",

}
print(datos_p)
for x in datos_p:
    print(x,datos_p[x])

print("La alumna", datos_p["nombre"], "es muy estudiosa")
print("Ella es de la carrera", datos_p['carrera'], "es una de las mejores en la carrera")
# Out:
# {'nombre': 'Mayra Naomi', 'matricula': 231690084, 'edad': 17, 'peso': 60, 'teléfono': 3111565245, 'domicilio': 'islas lilas', 'carrera': 'CDIA'}
# nombre Mayra Naomi
# matricula 231690084
# edad 17
# peso 60
# teléfono 3111565245
# domicilio islas lilas
# carrera CDIA
# La alumna Mayra Naomi es muy estudiosa
# Ella es de la carrera CDIA es una de las mejores en la carrera
